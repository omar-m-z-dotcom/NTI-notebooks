# %%
# !git clone https://github.com/Ahmedzedan0/ID_Card_Information_Extraction.git
# Out:
# Cloning into 'ID_Card_Information_Extraction'...
# remote: Enumerating objects: 148, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 148 (delta 1), reused 3 (delta 0), pack-reused 134
# Receiving objects: 100% (148/148), 122.59 MiB | 35.02 MiB/s, done.
# Resolving deltas: 100% (8/8), done.

# %%
# !cp -r /content/ID_Card_Information_Extraction /content/drive/MyDrive
