# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import numpy as np

# Create a list of column names, matching the expected number of columns in the data
column_names = ["mpg", "cylinders", "displacement", "horsepower", "weight", "acceleration", "model_year", "origin", "name"]

# Load the data using pandas.read_csv, specifying the column names and delimiter
data_url = "https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data"
df = pd.read_csv(data_url, sep='\s+', names=column_names,na_values="?")

# Print the first few rows of the DataFrame to verify it was loaded correctly
print(df.head())
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0  3504.0          12.0
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# 3  16.0          8         304.0       150.0  3433.0          12.0
# 4  17.0          8         302.0       140.0  3449.0          10.5
#
#    model_year  origin                       name
# 0          70       1  chevrolet chevelle malibu
# 1          70       1          buick skylark 320
# 2          70       1         plymouth satellite
# 3          70       1              amc rebel sst
# 4          70       1                ford torino

# %%
df = df.drop(axis=1, columns=["name"])
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      model_year  origin
# 0            70       1
# 1            70       1
# 2            70       1
# 3            70       1
# ...

# %%
# Assuming you have your DataFrame loaded as 'df'

# Create a MinMaxScaler object
scaler = MinMaxScaler(feature_range=(-1, 1))

# Normalize all columns (excluding potential non-numeric columns)
df_normalized = pd.DataFrame(scaler.fit_transform(df.select_dtypes(include=[np.number])), columns=df.columns)

# Print the normalized DataFrame
print(df_normalized)
# Out:
#           mpg  cylinders  displacement  horsepower    weight  acceleration  \
# 0   -0.521277        1.0      0.235142   -0.086957  0.072299     -0.523810
# 1   -0.680851        1.0      0.457364    0.293478  0.179473     -0.583333
# 2   -0.521277        1.0      0.291990    0.130435  0.033740     -0.642857
# 3   -0.627660        1.0      0.219638    0.130435  0.032039     -0.523810
# 4   -0.574468        1.0      0.209302    0.021739  0.041111     -0.702381
# ..        ...        ...           ...         ...       ...           ...
# 393 -0.042553       -0.6     -0.627907   -0.565217 -0.332577     -0.095238
# 394  0.861702       -0.6     -0.850129   -0.934783 -0.706833      0.976190
# 395  0.223404       -0.6     -0.653747   -0.586957 -0.613269     -0.571429
# 396  0.010638       -0.6     -0.731266   -0.641304 -0.426141      0.261905
# 397  0.170213       -0.6     -0.736434   -0.608696 -0.372271      0.357143
#
#      model_year  origin
# 0          -1.0    -1.0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Calculate correlation matrix
correlation_matrix = df_normalized.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import numpy as np

# Create a list of column names, matching the expected number of columns in the data
column_names = ["mpg", "cylinders", "displacement", "horsepower", "weight", "acceleration", "model_year", "origin", "name"]

# Load the data using pandas.read_csv, specifying the column names and delimiter
data_url = "https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data"
df_new = pd.read_csv(data_url, sep='\s+', names=column_names,na_values="?")

# Print the first few rows of the DataFrame to verify it was loaded correctly
print(df.head())
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0  3504.0          12.0
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# 3  16.0          8         304.0       150.0  3433.0          12.0
# 4  17.0          8         302.0       140.0  3449.0          10.5
#
#    model_year  origin
# 0          70       1
# 1          70       1
# 2          70       1
# 3          70       1
# 4          70       1

# %%
df_new = df_new.drop(axis=1, columns=["name"])
df_new
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      model_year  origin
# 0            70       1
# 1            70       1
# 2            70       1
# 3            70       1
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Calculate correlation matrix
correlation_matrix = df_new.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
df_new_x = df_new.drop(axis=1,columns=["mpg"])
df_new_x
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 0            8         307.0       130.0  3504.0          12.0          70
# 1            8         350.0       165.0  3693.0          11.5          70
# 2            8         318.0       150.0  3436.0          11.0          70
# 3            8         304.0       150.0  3433.0          12.0          70
# 4            8         302.0       140.0  3449.0          10.5          70
# ..         ...           ...         ...     ...           ...         ...
# 393          4         140.0        86.0  2790.0          15.6          82
# 394          4          97.0        52.0  2130.0          24.6          82
# 395          4         135.0        84.0  2295.0          11.6          82
# 396          4         120.0        79.0  2625.0          18.6          82
# 397          4         119.0        82.0  2720.0          19.4          82
#
#      origin
# 0         1
# 1         1
# 2         1
# 3         1
# ...

# %%
df_new_y = df_new["mpg"]
df_new_y
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
x_train,x_test,y_train,y_test = train_test_split(df_new_x,df_new_y,test_size=0.3,random_state=42)
print(f"x_train: {x_train.shape}")
print(f"y_train: {y_train.shape}")
print(f"x_test: {x_test.shape}")
print(f"y_test: {y_test.shape}")
# Out:
# x_train: (278, 7)
# y_train: (278,)
# x_test: (120, 7)
# y_test: (120,)
