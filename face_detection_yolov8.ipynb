# %% [markdown]
# #download the dataset

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="PCTykIn2SCMagnnLiOto")
project = rf.workspace("3mar-workspace").project("face_detection-sivcf")
version = project.version(5)
dataset = version.download("yolov8")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 10.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 11.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 12.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.9.0.80
#     Uninstalling opencv-python-headless-4.9.0.80:
#       Successfully uninstalled opencv-python-headless-4.9.0.80
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
# ...

# %% [markdown]
# #copying the dataset to permenant storege

# %%
# !cp -r "/content/face_detection-5" "/content/drive/MyDrive/Colab Notebooks/face_detection"

# %% [markdown]
# #installing the library used for training and inferance

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 749.1/749.1 kB 10.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 49.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 44.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 53.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 9.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 5.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 6.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# #training the model

# %%
from ultralytics import YOLO
import torch

device = 'cuda' if torch.cuda.is_available() else 'cpu'
# Load a model
model = YOLO('yolov8n.pt')

# Resume training
model.train(data='/content/drive/MyDrive/Colab Notebooks/face_detection/data.yaml',epochs=300, device=device)
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 114MB/s]
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# #copying the run results alonge with the trained model

# %%
import shutil

# Source folder path
source_folder = '/content/runs'

# Destination folder path
destination_folder = '/content/drive/MyDrive/Colab Notebooks/face_detection/runs'

# Copy the entire folder recursively
shutil.copytree(source_folder, destination_folder)
# Out:
# '/content/drive/MyDrive/Colab Notebooks/face_detection/runs'

# %%
from ultralytics import YOLO
from PIL import Image
from IPython.display import display

def crop_image(image_path, start_point, end_point):
    # Open the image
    image = Image.open(image_path)

    # Define the region of interest (ROI) using diagonal coordinates
    left = min(start_point[0], end_point[0])
    top = min(start_point[1], end_point[1])
    right = max(start_point[0], end_point[0])
    bottom = max(start_point[1], end_point[1])
    roi = (left, top, right, bottom)

    # Crop the image using the ROI
    cropped_image = image.crop(roi)

    return cropped_image

def get_detections(model_path,image_path):
  model = YOLO(model_path)
  source = image_path
  # Run inference on the source
  results = model(source)  # generator of Results objects
  detected_classes = {}

  for result in results:
    boxes = result.boxes.cpu().numpy()  # get boxes on cpu in numpy
    box_num = 0
    for box in boxes:
      cls = result.names[int(box.cls[0])]
      xyxy = list(box.numpy().xyxy[0]) # gets the diagonal of the detected object's rectangle [x_min, y_min, x_max, y_max]
      if cls == "face":
        detected_classes[box_num] = {"cls":cls, "xyxy":xyxy}
      xyxy = list(box.numpy().xyxy[0])
      if cls == "female":
        detected_classes[box_num] = {"cls":cls, "xyxy":xyxy}
      xyxy = list(box.numpy().xyxy[0])
      if cls == "male":
        detected_classes[box_num] = {"cls":cls, "xyxy":xyxy}
      box_num+=1

  print(detected_classes)

  #load the image
  image = Image.open(image_path)

  cropped_image = None # the final cropped image
  sex = None # the sex of the person in the image which will be useful when we come up with random names for this person

  for key in detected_classes:
    print(detected_classes[key])
    if detected_classes[key]['cls'] == 'face':
      xyxy = detected_classes[key]['xyxy']
      # Define rectangle parameters
      start_point = (xyxy[0], xyxy[1])  # Top left corner
      end_point = (xyxy[2], xyxy[3]) # bottom right corner
      cropped_image = crop_image(image_path, start_point, end_point)
      display(cropped_image)
    elif detected_classes[key]['cls'] == 'female' or detected_classes[key]['cls'] == 'male':
      sex = detected_classes[key]['cls']
      print(type(sex))

  return cropped_image, sex



cropped_image, sex = get_detections('/content/drive/MyDrive/Colab Notebooks/face_detection/runs/detect/train/weights/best.pt','/content/drive/MyDrive/Colab Notebooks/face_detection/test/images/WhatsApp-Image-2024-03-31-at-11-01-25_cb896c05_jpg.rf.0a711f318e2f4cc44343c38727764529.jpg')

cropped_image, sex
# Out:
# image 1/1 /content/drive/MyDrive/Colab Notebooks/face_detection/test/images/WhatsApp-Image-2024-03-31-at-11-01-25_cb896c05_jpg.rf.0a711f318e2f4cc44343c38727764529.jpg: 640x640 1 face, 1 female, 288.2ms
# Speed: 7.3ms preprocess, 288.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# {0: {'cls': 'face', 'xyxy': [90.36432, 463.35727, 388.86957, 633.19324]}, 1: {'cls': 'female', 'xyxy': [89.745544, 470.8847, 388.32733, 634.263]}}
# {'cls': 'face', 'xyxy': [90.36432, 463.35727, 388.86957, 633.19324]}
# <PIL.Image.Image image mode=RGB size=299x170>
# {'cls': 'female', 'xyxy': [89.745544, 470.8847, 388.32733, 634.263]}
# <class 'str'>
# (<PIL.Image.Image image mode=RGB size=299x170>, 'female')

# %%
# model = YOLO('/content/drive/MyDrive/Colab Notebooks/training folder/runs/detect/train3/weights/last.pt')
# model.train(resume=True)
